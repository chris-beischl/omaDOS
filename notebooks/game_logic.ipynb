# %%
# %load_ext autoreload
# %autoreload 2

# %%
from omados.engine.cards import Suit
from omados.engine.game_2 import get_cards
from omados.engine.rules import get_legal_moves
from omados.engine.modes import *

# %%
gamemode = GameModeFactory.create_sauspiel(1, Suit.Eichel)
gamemode

# %%
gamemode.rufsau

# %%
hand = get_cards()[0]
hand = Cards(['EO', 'GO', 'EA', 'E9', 'E8', 'E7', 'S10', 'S9'])
hand = Cards(['EO', 'GO', 'EA', 'E9', 'E8', 'SK', 'S10', 'S9'])
hand

# %%
get_legal_moves(hand, 18, gamemode)
