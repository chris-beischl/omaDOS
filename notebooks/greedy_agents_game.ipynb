# %%
# %load_ext autoreload
# %autoreload 2


from omados.agents.greedy import GreedyAgent, BaseAgent
from omados.env.game import SchafkopfEnv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
agents : list[BaseAgent] = [GreedyAgent(player_id) for player_id in range(4)]
env = SchafkopfEnv(agents=agents)

env.play_game()
# Out:
# GameContract(spielart='Sauspiel', trumpf_cards=Cards(['EO', 'GO', 'HO', 'SO', 'EU', 'GU', 'HU', 'SU', 'HA', 'H10', 'HK', 'H9', 'H8', 'H7']), rufsau_suit=<Suit.Gras: 'G'>, caller_id=1)
# Trick 1, Leader
# 	Player 1 	Hand: Cards(['EO', 'H10', 'HK', 'EA', 'EK', 'E9', 'GK', 'G8'])
# 			Legal Moves: Cards(['EO', 'H10', 'HK', 'EA', 'EK', 'E9', 'GK', 'G8'])
# 	Player 2 	Hand: Cards(['HO', 'GU', 'H8', 'E10', 'E7', 'G9', 'SA', 'S8'])
# 			Legal Moves: Cards(['E10', 'E7'])
# 	Player 3 	Hand: Cards(['HU', 'SU', 'HA', 'H7', 'E8', 'GA', 'S9', 'S7'])
# 			Legal Moves: Cards(['E8'])
# 	Player 0 	Hand: Cards(['GO', 'SO', 'EU', 'H9', 'G10', 'G7', 'S10', 'SK'])
# 			Legal Moves: Cards(['GO', 'SO', 'EU', 'H9', 'G10', 'G7', 'S10', 'SK'])
# Trick 2, Leader
# 	Player 3 	Hand: Cards(['HU', 'SU', 'HA', 'H7', 'E8', 'GA', 'S9', 'S7'])
# 			Legal Moves: Cards(['HU', 'SU', 'HA', 'H7', 'E8', 'GA', 'S9', 'S7'])
# 	Player 0 	Hand: Cards(['GO', 'SO', 'EU', 'H9', 'G7', 'S10', 'SK'])
# 			Legal Moves: Cards(['SO', 'EU', 'H9'])
# 	Player 1 	Hand: Cards(['EO', 'H10', 'HK', 'EK', 'E9', 'GK', 'G8'])
# 			Legal Moves: Cards(['EO', 'H10', 'HK'])
# 	Player 2 	Hand: Cards(['HO', 'GU', 'H8', 'E7', 'G9', 'SA', 'S8'])
# 			Legal Moves: Cards(['HO', 'H8'])
# Trick 3, Leader
# 	Player 2 	Hand: Cards(['GU', 'H8', 'E7', 'G9', 'SA', 'S8'])
# 			Legal Moves: Cards(['GU', 'H8', 'E7', 'G9', 'SA', 'S8'])
# 	Player 3 	Hand: Cards(['HU', 'SU', 'H7', 'E8', 'GA', 'S9', 'S7'])
# 			Legal Moves: Cards(['S9', 'S7'])
# 	Player 0 	Hand: Cards(['GO', 'EU', 'H9', 'G7', 'S10', 'SK'])
# 			Legal Moves: Cards(['S10', 'SK'])
# 	Player 1 	Hand: Cards(['EO', 'HK', 'EK', 'E9', 'GK', 'G8'])
# 			Legal Moves: Cards(['EO', 'HK', 'EK', 'E9', 'GK', 'G8'])
# Trick 4, Leader
# 	Player 3 	Hand: Cards(['HU', 'SU', 'H7', 'E8', 'GA', 'S9', 'S7'])
# 			Legal Moves: Cards(['HU', 'SU', 'H7', 'E8', 'GA', 'S9', 'S7'])
# 	Player 0 	Hand: Cards(['GO', 'EU', 'H9', 'G7', 'SK'])
# 			Legal Moves: Cards([])
# 	Player 1 	Hand: Cards(['EO', 'EK', 'E9', 'GK', 'G8'])
# 			Legal Moves: Cards([])
# 	Player 2 	Hand: Cards(['GU', 'H8', 'E7', 'G9', 'S8'])
# 			Legal Moves: Cards([])
# Trick 5, Leader
# 	Player 0 	Hand: Cards(['GO', 'EU', 'H9', 'G7', 'SK'])
# 			Legal Moves: Cards(['GO', 'EU', 'H9', 'G7', 'SK'])
# 	Player 1 	Hand: Cards(['EK', 'E9', 'GK', 'G8'])
# 			Legal Moves: Cards(['EK', 'E9', 'GK', 'G8'])
# 	Player 2 	Hand: Cards(['GU', 'H8', 'E7', 'G9', 'S8'])
# 			Legal Moves: Cards(['S8'])
# 	Player 3 	Hand: Cards(['HU', 'SU', 'H7', 'E8', 'S9', 'S7'])
# 			Legal Moves: Cards(['S9', 'S7'])
# Trick 6, Leader
# 	Player 2 	Hand: Cards(['GU', 'H8', 'E7', 'G9', 'S8'])
# 			Legal Moves: Cards(['GU', 'H8', 'E7', 'G9', 'S8'])
# 	Player 3 	Hand: Cards(['HU', 'SU', 'H7', 'E8', 'S9', 'S7'])
# 			Legal Moves: Cards(['HU', 'SU', 'H7'])
# 	Player 0 	Hand: Cards(['GO', 'EU', 'H9', 'G7'])
# 			Legal Moves: Cards(['EU', 'H9'])
# 	Player 1 	Hand: Cards(['E9', 'GK', 'G8'])
# 			Legal Moves: Cards(['E9', 'GK', 'G8'])
# Trick 7, Leader
# 	Player 0 	Hand: Cards(['GO', 'H9', 'G7'])
# 			Legal Moves: Cards(['GO', 'H9', 'G7'])
# 	Player 1 	Hand: Cards(['E9', 'G8'])
# 			Legal Moves: Cards(['E9', 'G8'])
# 	Player 2 	Hand: Cards(['H8', 'E7', 'G9', 'S8'])
# 			Legal Moves: Cards(['H8'])
# 	Player 3 	Hand: Cards(['SU', 'H7', 'E8', 'S9', 'S7'])
# 			Legal Moves: Cards(['SU', 'H7'])
# Trick 8, Leader
# 	Player 1 	Hand: Cards(['E9', 'G8'])
# 			Legal Moves: Cards(['E9', 'G8'])
# 	Player 2 	Hand: Cards(['H8', 'E7', 'G9', 'S8'])
# 			Legal Moves: Cards(['H8'])
# 	Player 3 	Hand: Cards(['H7', 'E8', 'S9', 'S7'])
# 			Legal Moves: Cards(['H7'])
# 	Player 0 	Hand: Cards(['H9', 'G7'])
# 			Legal Moves: Cards(['H9'])
# (tensor([30., 23., 41., 62.]),
#  GameContract(spielart='Sauspiel', trumpf_cards=Cards(['EO', 'GO', 'HO', 'SO', 'EU', 'GU', 'HU', 'SU', 'HA', 'H10', 'HK', 'H9', 'H8', 'H7']), rufsau_suit=<Suit.Gras: 'G'>, caller_id=1))
